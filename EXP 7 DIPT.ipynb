# %% [markdown]
# ### EX-07 EDGE LINKING HOUGH TRANSFORM

# %% [markdown]
# ### NAME : SAJITH AHAMED F

# %% [markdown]
# ### REG NO : 212223240144

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
img=cv2.imread("",0)
img_c=cv2.imread("VI.jpeg",1)
img_c=cv2.cvtColor(img_c,cv2.COLOR_BGR2RGB)
gray=cv2.cvtColor(img,cv2.COLOR_GRAY2RGB)
gray = cv2.GaussianBlur(gray,(3,3),0)
plt.figure(figsize=(13,13))
plt.subplot(1,2,1)
plt.imshow(img_c)
plt.title("Original Image")
plt.axis("off")
plt.subplot(1,2,2)
plt.imshow(gray)
plt.title("Gray Image")
plt.axis("off")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[2], line 6
#       4 img=cv2.imread("VI.jpeg",0)
#       5 img_c=cv2.imread("VI.jpeg",1)
# ----> 6 img_c=cv2.cvtColor(img_c,cv2.COLOR_BGR2RGB)
#       7 gray=cv2.cvtColor(img,cv2.COLOR_GRAY2RGB)
#       8 gray = cv2.GaussianBlur(gray,(3,3),0)
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
